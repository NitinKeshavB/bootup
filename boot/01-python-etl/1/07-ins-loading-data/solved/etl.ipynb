# %%
import requests
import pandas as pd 
from secrets_config import api_key # https://home.openweathermap.org/

# %%
# how to extract data from multiple cities? e.g. canberra, sydney, etc

# 1. create a list of cities (csv)
# 2. read list of cities (csv) 
# 3. request data for each city (json) and push to a list 
# 4. convert list into dataframe

# %%
# read list of cities
df_cities = pd.read_csv("data/australian_capital_cities.csv")
df_cities.head()
# Out:
#   city_name
# 0  canberra
# 1    sydney
# 2    darwin
# 3  brisbane
# 4  adelaide

# %%
# request data for each city (json) and push to a list 
weather_data = []
for city_name in df_cities["city_name"]:
    params = {
        "q": city_name,
        "units": "metric",
        "appid": api_key
    }
    response = requests.get(f"http://api.openweathermap.org/data/2.5/weather", params=params)
    if response.status_code == 200: 
        weather_data.append(response.json())
    else: 
        raise Exception("Extracting weather api data failed. Please check if API limits have been reached.")

# %%
# show requested data 
print(weather_data)
# Out:
# [{'coord': {'lon': 149.1281, 'lat': -35.2835}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 1.08, 'feels_like': 1.08, 'temp_min': -1.61, 'temp_max': 6.49, 'pressure': 1021, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 8}, 'dt': 1657722339, 'sys': {'type': 1, 'id': 9588, 'country': 'AU', 'sunrise': 1657746606, 'sunset': 1657782482}, 'timezone': 36000, 'id': 2172517, 'name': 'Canberra', 'cod': 200}, {'coord': {'lon': 151.2073, 'lat': -33.8679}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 10.35, 'feels_like': 9.43, 'temp_min': 9.03, 'temp_max': 11.3, 'pressure': 1015, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 210}, 'rain': {'1h': 2.05}, 'clouds': {'all': 100}, 'dt': 1657722281, 'sys': {'type': 2, 'id': 2002865, 'country': 'AU', 'sunrise': 1657745905, 'sunset': 1657782185}, 'timezone': 36000, 'id': 2147714, 'name': 'Sydney', 'cod': 200}, {'coord': {'lon': 130.8418, 'lat': -12.4611}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 19.12, 'feels_like': 18.03, 'temp_min': 17.72, 'temp_max': 19.99, 'pressure': 1014, 'humidity': 36}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 160}, 'clouds': {'all': 0}, 'dt': 1657722597, 'sys': {'type': 1, 'id': 9574, 'country': 'AU', 'sunrise': 1657661928, 'sunset': 1657703125}, 'timezone': 34200, 'id': 2073124, 'name': 'Darwin', 'cod': 200}, {'coord': {'lon': 153.0281, 'lat': -27.4679}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 10.01, 'feels_like': 8.82, 'temp_min': 7.76, 'temp_max': 10.8, 'pressure': 1013, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 4.63, 'deg': 250}, 'clouds': {'all': 0}, 'dt': 1657722443, 'sys': {'type': 2, 'id': 2005393, 'country': 'AU', 'sunrise': 1657744634, 'sunset': 1657782582}, 'timezone': 36000, 'id': 2174003, 'name': 'Brisbane', 'cod': 200}, {'coord': {'lon': 138.6, 'lat': -34.9333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 9.09, 'feels_like': 7.7, 'temp_min': 7.49, 'temp_max': 10.74, 'pressure': 1027, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 140}, 'clouds': {'all': 75}, 'dt': 1657722245, 'sys': {'type': 2, 'id': 2001763, 'country': 'AU', 'sunrise': 1657662704, 'sunset': 1657698625}, 'timezone': 34200, 'id': 2078025, 'name': 'Adelaide', 'cod': 200}, {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 3.17, 'feels_like': 0.24, 'temp_min': 2.37, 'temp_max': 3.92, 'pressure': 1018, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 300}, 'clouds': {'all': 40}, 'dt': 1657722599, 'sys': {'type': 2, 'id': 2002195, 'country': 'AU', 'sunrise': 1657748280, 'sunset': 1657781672}, 'timezone': 36000, 'id': 2163355, 'name': 'Hobart', 'cod': 200}, {'coord': {'lon': -80.6081, 'lat': 28.0836}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 30.83, 'feels_like': 37.83, 'temp_min': 29.46, 'temp_max': 32.81, 'pressure': 1019, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 260}, 'clouds': {'all': 40}, 'dt': 1657722318, 'sys': {'type': 2, 'id': 2007578, 'country': 'US', 'sunrise': 1657708471, 'sunset': 1657758086}, 'timezone': -14400, 'id': 4163971, 'name': 'Melbourne', 'cod': 200}, {'coord': {'lon': 115.8333, 'lat': -31.9333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 15.62, 'feels_like': 15.48, 'temp_min': 14.07, 'temp_max': 17.66, 'pressure': 1013, 'humi ...

# %%
# convert list into dataframe 
df_weather_cities = pd.json_normalize(weather_data)
df_weather_cities.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
# 1  [{'id': 501, 'main': 'Rain', 'description': 'm...  stations       10000
# 2  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
# 3  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
# 4  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id      name  cod  coord.lon  coord.lat  ...  \
# 0  1657722339     36000  2172517  Canberra  200   149.1281   -35.2835  ...
# 1  1657722281     36000  2147714    Sydney  200   151.2073   -33.8679  ...
# 2  1657722597     34200  2073124    Darwin  200   130.8418   -12.4611  ...
# 3  1657722443     36000  2174003  Brisbane  200   153.0281   -27.4679  ...
# 4  1657722245     34200  2078025  Adelaide  200   138.6000   -34.9333  ...
#
#    main.humidity  wind.speed  wind.deg  clouds.all  sys.type   sys.id  \
# 0             88        0.00         0           8         1     9588
# 1             76       10.29       210         100         2  2002865
# 2             36        3.09       160           0         1     9574
# 3             67        4.63       250           0         2  2005393
# 4             82        2.57       140          75         2  2001763
#
#    sys.country  sys.sunrise  sys.sunset  rain.1h
# 0           AU   1657746606  1657782482      NaN
# 1           AU   1657745905  1657782185     2.05
# 2           AU   1657661928  1657703125      NaN
# 3           AU   1657744634  1657782582      NaN
# 4           AU   1657662704  1657698625      NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Transforming data

# %%
# set city names to lowercase 
df_weather_cities["city_name"] = df_weather_cities["name"].str.lower()

# %%
df_population = pd.read_csv("data/australian_city_population.csv")
df_population.head()
# Out:
#   city_name  population
# 0  canberra      431611
# 1    sydney     5361466
# 2    darwin      146982
# 3  brisbane     2582007
# 4  adelaide     1378413

# %%
df_merged = pd.merge(left=df_weather_cities, right=df_population, on=["city_name"])
df_merged.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
# 1  [{'id': 501, 'main': 'Rain', 'description': 'm...  stations       10000
# 2  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
# 3  [{'id': 800, 'main': 'Clear', 'description': '...  stations       10000
# 4  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id      name  cod  coord.lon  coord.lat  ...  \
# 0  1657722339     36000  2172517  Canberra  200   149.1281   -35.2835  ...
# 1  1657722281     36000  2147714    Sydney  200   151.2073   -33.8679  ...
# 2  1657722597     34200  2073124    Darwin  200   130.8418   -12.4611  ...
# 3  1657722443     36000  2174003  Brisbane  200   153.0281   -27.4679  ...
# 4  1657722245     34200  2078025  Adelaide  200   138.6000   -34.9333  ...
#
#    wind.deg  clouds.all  sys.type   sys.id  sys.country  sys.sunrise  \
# 0         0           8         1     9588           AU   1657746606
# 1       210         100         2  2002865           AU   1657745905
# 2       160           0         1     9574           AU   1657661928
# 3       250           0         2  2005393           AU   1657744634
# 4       140          75         2  2001763           AU   1657662704
#
#    sys.sunset  rain.1h  city_name  population
# 0  1657782482      NaN   canberra      431611
# 1  1657782185     2.05     sydney     5361466
# 2  1657703125      NaN     darwin      146982
# 3  1657782582      NaN   brisbane     2582007
# 4  1657698625      NaN   adelaide     1378413
#
# [5 rows x 27 columns]

# %%
# print out all columns and pick only relevant ones 
df_merged.columns
# Out:
# Index(['weather', 'base', 'visibility', 'dt', 'timezone', 'id', 'name', 'cod',
#        'coord.lon', 'coord.lat', 'main.temp', 'main.feels_like',
#        'main.temp_min', 'main.temp_max', 'main.pressure', 'main.humidity',
#        'wind.speed', 'wind.deg', 'clouds.all', 'sys.type', 'sys.id',
#        'sys.country', 'sys.sunrise', 'sys.sunset', 'rain.1h', 'city_name',
#        'population'],
#       dtype='object')

# %%
df_selected = df_merged[["dt", "id", "name", "main.temp", "population"]] 
df_selected.head()
# Out:
#            dt       id      name  main.temp  population
# 0  1657722339  2172517  Canberra       1.08      431611
# 1  1657722281  2147714    Sydney      10.35     5361466
# 2  1657722597  2073124    Darwin      19.12      146982
# 3  1657722443  2174003  Brisbane      10.01     2582007
# 4  1657722245  2078025  Adelaide       9.09     1378413

# %%
df_selected.dtypes
# Out:
# dt              int64
# id              int64
# name           object
# main.temp     float64
# population      int64
# dtype: object

# %%
df_selected["unique_id"] = df_selected["dt"].astype(str) + df_selected["id"].astype(str)
# Out:
# /var/folders/36/62h2k_3s07vbf145yklkj8740000gn/T/ipykernel_39590/4145054097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["unique_id"] = df_selected["dt"].astype(str) + df_selected["id"].astype(str)

# %%
# convert unix timestamp column to datetime 
df_selected["dt"] = pd.to_datetime(df_selected["dt"], unit="s")
df_selected.head()
# Out:
# /var/folders/36/62h2k_3s07vbf145yklkj8740000gn/T/ipykernel_39590/1191350713.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected["dt"] = pd.to_datetime(df_selected["dt"], unit="s")
#                    dt       id      name  main.temp  population  \
# 0 2022-07-13 14:25:39  2172517  Canberra       1.08      431611
# 1 2022-07-13 14:24:41  2147714    Sydney      10.35     5361466
# 2 2022-07-13 14:29:57  2073124    Darwin      19.12      146982
# 3 2022-07-13 14:27:23  2174003  Brisbane      10.01     2582007
# 4 2022-07-13 14:24:05  2078025  Adelaide       9.09     1378413
#
#            unique_id
# 0  16577223392172517
# 1  16577222812147714
# 2  16577225972073124
# 3  16577224432174003
# 4  16577222452078025

# %%
# rename colum names to more meaningful names
df_selected = df_selected.rename(columns={
    "dt": "datetime",
    "main.temp": "temperature"
})
df_selected.head()
# Out:
#              datetime       id      name  temperature  population  \
# 0 2022-07-13 14:25:39  2172517  Canberra         1.08      431611
# 1 2022-07-13 14:24:41  2147714    Sydney        10.35     5361466
# 2 2022-07-13 14:29:57  2073124    Darwin        19.12      146982
# 3 2022-07-13 14:27:23  2174003  Brisbane        10.01     2582007
# 4 2022-07-13 14:24:05  2078025  Adelaide         9.09     1378413
#
#            unique_id
# 0  16577223392172517
# 1  16577222812147714
# 2  16577225972073124
# 3  16577224432174003
# 4  16577222452078025

# %%
df_selected = df_selected.set_index(["unique_id"])

# %% [markdown]
# ### Load data to file (parquet)

# %% [markdown]
# Overwrite

# %%
# load (overwrite) data to a csv file 
df_selected.to_parquet("data/weather.parquet")

# %% [markdown]
# Upsert

# %%
import os 

# upsert (update and insert) data to a csv file 
if "weather.parquet" in os.listdir("data/"): 
    df_current = pd.read_parquet("data/weather.parquet")
    df_concat = pd.concat(objs=[df_current,df_selected[~df_selected.index.isin(df_current.index)]]) # ~: converts true to false, and false to true. 
    df_concat.to_parquet("data/weather.parquet")
else:
    df_selected.to_parquet("data/weather.parquet")

# %%
pd.read_parquet("data/weather.parquet")
# Out:
#                              datetime       id       name  temperature  \
# unique_id
# 16574952652172517 2022-07-10 23:21:05  2172517   Canberra         4.05
# 16574953552147714 2022-07-10 23:22:35  2147714     Sydney        11.16
# 16574952862073124 2022-07-10 23:21:26  2073124     Darwin        19.85
# 16574954332174003 2022-07-10 23:23:53  2174003   Brisbane        12.62
# 16574952122078025 2022-07-10 23:20:12  2078025   Adelaide        10.89
# 16574953222163355 2022-07-10 23:22:02  2163355     Hobart         7.32
# 16574952504163971 2022-07-10 23:20:50  4163971  Melbourne        30.03
# 16574954722063523 2022-07-10 23:24:32  2063523      Perth         4.70
#
#                    population
# unique_id
# 16574952652172517      431611
# 16574953552147714     5361466
# 16574952862073124      146982
# 16574954332174003     2582007
# 16574952122078025     1378413
# 16574953222163355      238375
# 16574952504163971     5096298
# 16574954722063523     2141834

# %% [markdown]
# Append new files

# %%
import datetime as dt 
current_timestamp = dt.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")
df_selected.to_parquet(f"data/weather_{current_timestamp}.parquet")

# %% [markdown]
# ### Load data to SQL

# %%
from sqlalchemy import create_engine, Table, Column, Integer, String, MetaData, Float # https://www.tutorialspoint.com/sqlalchemy/sqlalchemy_core_creating_table.htm
from sqlalchemy.engine import URL
from sqlalchemy.dialects import postgresql
from secrets_config import db_user, db_password, db_server_name, db_database_name
from sqlalchemy.schema import CreateTable

# %%
# create connection to database 
connection_url = URL.create(
    drivername = "postgresql+pg8000", 
    username = db_user,
    password = db_password,
    host = db_server_name, 
    port = 5432,
    database = db_database_name, 
)

engine = create_engine(connection_url)

# %% [markdown]
# Insert

# %%
df_selected.to_sql("weather_ins", engine)
# Out:
# 8

# %% [markdown]
# Upsert

# %%
meta = MetaData()
weather_table = Table(
    "weather", meta, 
    Column("datetime", String, primary_key=True),
    Column("id", Integer, primary_key=True),
    Column("name", String),
    Column("temperature", Float),
    Column("population", Integer)
)
meta.create_all(engine) # creates table if it does not exist

# %%
insert_statement = postgresql.insert(weather_table).values(df_selected.to_dict(orient='records'))
upsert_statement = insert_statement.on_conflict_do_update(
    index_elements=['id', 'datetime'],
    set_={c.key: c for c in insert_statement.excluded if c.key not in ['id', 'datetime']})
engine.execute(upsert_statement)
